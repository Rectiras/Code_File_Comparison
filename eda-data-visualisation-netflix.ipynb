# %% [markdown]
# ![Netflix](http://i2.wp.com/tvrev.com/wp-content/uploads/2020/02/thibault-penin-AWOl7qqsffM-unsplash-scaled.jpg?fit=2560%2C1709&ssl=1)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../input/netflix-original-films-imdb-scores/NetflixOriginals.csv")
df.head()
# Out:
#              Title                  Genre           Premiere  Runtime  \
# 0  Enter the Anime            Documentary     August 5, 2019       58
# 1      Dark Forces               Thriller    August 21, 2020       81
# 2          The App  Science fiction/Drama  December 26, 2019       79
# 3   The Open House        Horror thriller   January 19, 2018       94
# 4      Kaali Khuhi                Mystery   October 30, 2020       90
#
#    IMDB Score          Language
# 0         2.5  English/Japanese
# 1         2.6           Spanish
# 2         2.6           Italian
# 3         3.2           English
# 4         3.4             Hindi

# %%
df.shape
# Out:
# (584, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       584 non-null    object
#  1   Genre       584 non-null    object
#  2   Premiere    584 non-null    object
#  3   Runtime     584 non-null    int64
#  4   IMDB Score  584 non-null    float64
#  5   Language    584 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 27.5+ KB

# %%
df.Genre.value_counts()
# Out:
# Documentary            159
# Drama                   77
# Comedy                  49
# Romantic comedy         39
# Thriller                33
#                       ...
# Family/Comedy-drama      1
# Historical drama         1
# Musical / Short          1
# Christmas musical        1
# War-Comedy               1
# Name: Genre, Length: 115, dtype: int64

# %%
df.describe()
# Out:
#           Runtime  IMDB Score
# count  584.000000  584.000000
# mean    93.577055    6.271747
# std     27.761683    0.979256
# min      4.000000    2.500000
# 25%     86.000000    5.700000
# 50%     97.000000    6.350000
# 75%    108.000000    7.000000
# max    209.000000    9.000000

# %%
score_8 = df[df['IMDB Score']>=8]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

plt.figure(figsize = (12,12))
sns.barplot(x = 'IMDB Score', y = 'Title',hue ='Genre', data = score_8)
# Out:
# <AxesSubplot:xlabel='IMDB Score', ylabel='Title'>

# %%
fig = px.bar(score_8, x='IMDB Score', y= 'Title', color='Genre')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="8fdc1513-4a21-4a8c-a2db-864071eff818" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fdc1513-4a21-4a8c-a2db-864071eff818")) {                    Plotly.newPlot(                        "8fdc1513-4a21-4a8c-a2db-864071eff818",                        [{"alignmentgroup": "True", "hovertemplate": "Genre=Documentary<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Documentary", "marker": {"color": "#636efa"}, "name": "Documentary", "offsetgroup": "Documentary", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [8.0, 8.1, 8.1, 8.1, 8.2, 8.2, 8.2, 8.2, 8.3, 8.3, 8.4, 8.6, 9.0], "xaxis": "x", "y": ["Struggle: The Life and Lost Art of Szukaiski", "Chasing Coral ", "My Octopus Teacher", "Rising Phoenix", "13th", "Disclosure: Trans Lives on Screen", "Seaspiracy", "The Three Deaths of Marisela Escobedo", "Cuba and the Cameraman ", "Dancing with the Birds", "Winter on Fire: Ukraine's Fight for Freedom", "Emicida: AmarElo - It's All For Yesterday", "David Attenborough: A Life on Our Planet"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=Animation/Christmas/Comedy/Adventure<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Animation/Christmas/Comedy/Adventure", "marker": {"color": "#EF553B"}, "name": "Animation/Christmas/Comedy/Adventure", "offsetgroup": "Animation/Christmas/Comedy/Adventure", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [8.2], "xaxis": "x", "y": ["Klaus"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=Concert Film<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Concert Film", "marker": {"color": "#00cc96"}, "name": "Concert Film", "offsetgroup": "Concert Film", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [8.4, 8.4], "xaxis": "x", "y": ["Ben Platt: Live from Radio City Music Hall", "Taylor Swift: Reputation Stadium Tour"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=One-man show<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "One-man show", "marker": {"color": "#ab63fa"}, "name": "One-man show", "offsetgroup": "One-man show", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [8.5], "xaxis": "x", "y": ["Springsteen on Broadway"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "Genre"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0 ...

# %% [markdown]
# ## Above are the movies which have ratings 8 or more

# %%
sns.set(rc={'figure.figsize':(20,18)})
score_5 = df[df['IMDB Score']<5]
sns.barplot(x="IMDB Score", y="Title",data=score_5)
# Out:
# <AxesSubplot:xlabel='IMDB Score', ylabel='Title'>

# %%
fig = px.bar(score_5, x='IMDB Score', y= 'Title', color='Genre')
fig.show()
# Out:
# <div>                            <div id="9c2247b1-9489-4d95-b344-8b0b68ddbfe4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c2247b1-9489-4d95-b344-8b0b68ddbfe4")) {                    Plotly.newPlot(                        "9c2247b1-9489-4d95-b344-8b0b68ddbfe4",                        [{"alignmentgroup": "True", "hovertemplate": "Genre=Documentary<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Documentary", "marker": {"color": "#636efa"}, "name": "Documentary", "offsetgroup": "Documentary", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2.5, 4.1, 4.3, 4.4, 4.6, 4.6], "xaxis": "x", "y": ["Enter the Anime", "Searching for Sheela", "After the Raid", "Hello Privilege. It's Me, Chelsea", "After Maria", "We Are One"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=Thriller<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Thriller", "marker": {"color": "#EF553B"}, "name": "Thriller", "offsetgroup": "Thriller", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2.6, 4.2, 4.4, 4.4, 4.5, 4.8, 4.8], "xaxis": "x", "y": ["Dark Forces", "Mercy", "Secret Obsession", "The Girl on the Train", "Fatal Affair", "Christmas Crossfire", "Mrs. Serial Killer"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=Science fiction/Drama<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Science fiction/Drama", "marker": {"color": "#00cc96"}, "name": "Science fiction/Drama", "offsetgroup": "Science fiction/Drama", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2.6, 4.7], "xaxis": "x", "y": ["The App", "IO"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=Horror thriller<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Horror thriller", "marker": {"color": "#ab63fa"}, "name": "Horror thriller", "offsetgroup": "Horror thriller", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3.2, 4.4], "xaxis": "x", "y": ["The Open House", "Death Note"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=Mystery<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Mystery", "marker": {"color": "#FFA15A"}, "name": "Mystery", "offsetgroup": "Mystery", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3.4], "xaxis": "x", "y": ["Kaali Khuhi"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=Action<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Action", "marker": {"color": "#19d3f3"}, "name": "Action", "offsetgroup": "Action", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3.5, 4.7, 4.9], "xaxis": "x", "y": ["Drive", "Sentinelle", "Earth and Blood"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=Comedy<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Comedy", "marker": {"color": "#FF6692"}, "name": "Comedy", "offsetgroup": "Comedy", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [3.7, 4.1, 4.3, 4.4, 4.5, 4.5, 4.6, 4.6, 4.6, 4.8, 4.8], "xaxis": "x", "y": ["Leyla Everlasting", "Sardar Ka Grandson", "What Happened to Mr. Cha?", "Sextuplets", "Seriously Single", "The Misadventures of Hedi and Cokeman", "5 Star Christmas", "Porta dos Fundos: The First Temptation of Christ", "The Players", "Take the 10", "The Main Event"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Genre=Heist film/Thriller<br>IMDB Score=%{x}<br>Title=%{y}<extra></extra>", "legendgroup": "Heist film/Thriller", "marker": {"color": "#B6E880"}, "name": "Heist film/Thriller", "offsetgroup": "Hei ...

# %% [markdown]
# # Above are the movies which have ratings less than 5

# %%
genre_low = df[df['IMDB Score']<5][['Genre','Title', 'IMDB Score','Language']].sort_values('IMDB Score', ascending = True)

# %%
genre_low[:15]
# Out:
#                       Genre                            Title  IMDB Score  \
# 0               Documentary                  Enter the Anime         2.5
# 1                  Thriller                      Dark Forces         2.6
# 2     Science fiction/Drama                          The App         2.6
# 3           Horror thriller                   The Open House         3.2
# 4                   Mystery                      Kaali Khuhi         3.4
# 5                    Action                            Drive         3.5
# 6                    Comedy                Leyla Everlasting         3.7
# 7       Heist film/Thriller  The Last Days of American Crime         3.7
# 8   Musical/Western/Fantasy                          Paradox         3.9
# 9                    Comedy               Sardar Ka Grandson         4.1
# 10              Documentary             Searching for Sheela         4.1
# 11                    Drama                         The Call         4.1
# 12          Romantic comedy                          Whipped         4.1
# 14                 Thriller                            Mercy         4.2
# 13            Action comedy               All Because of You         4.2
#
#             Language
# 0   English/Japanese
# 1            Spanish
# 2            Italian
# 3            English
# 4              Hindi
# 5              Hindi
# 6            Turkish
# 7            English
# 8            English
# 9              Hindi
# 10           English
# 11            Korean
# 12        Indonesian
# 14           English
# 13             Malay

# %%
sns.catplot(x="Genre", kind="count", data=genre_low[:17], aspect= 50.7/11.2)

# %%
fig = px.bar(genre_low, x='Genre', y= 'IMDB Score', color = 'Title')
fig.show()
# Out:
# <div>                            <div id="ffe4d363-c268-4aba-9e6c-3302111294a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffe4d363-c268-4aba-9e6c-3302111294a4")) {                    Plotly.newPlot(                        "ffe4d363-c268-4aba-9e6c-3302111294a4",                        [{"alignmentgroup": "True", "hovertemplate": "Title=Enter the Anime<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Enter the Anime", "marker": {"color": "#636efa"}, "name": "Enter the Anime", "offsetgroup": "Enter the Anime", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Documentary"], "xaxis": "x", "y": [2.5], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=Dark Forces<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Dark Forces", "marker": {"color": "#EF553B"}, "name": "Dark Forces", "offsetgroup": "Dark Forces", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Thriller"], "xaxis": "x", "y": [2.6], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=The App<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "The App", "marker": {"color": "#00cc96"}, "name": "The App", "offsetgroup": "The App", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Science fiction/Drama"], "xaxis": "x", "y": [2.6], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=The Open House<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "The Open House", "marker": {"color": "#ab63fa"}, "name": "The Open House", "offsetgroup": "The Open House", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Horror thriller"], "xaxis": "x", "y": [3.2], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=Kaali Khuhi<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Kaali Khuhi", "marker": {"color": "#FFA15A"}, "name": "Kaali Khuhi", "offsetgroup": "Kaali Khuhi", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Mystery"], "xaxis": "x", "y": [3.4], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=Drive<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Drive", "marker": {"color": "#19d3f3"}, "name": "Drive", "offsetgroup": "Drive", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Action"], "xaxis": "x", "y": [3.5], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=Leyla Everlasting<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Leyla Everlasting", "marker": {"color": "#FF6692"}, "name": "Leyla Everlasting", "offsetgroup": "Leyla Everlasting", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Comedy"], "xaxis": "x", "y": [3.7], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=The Last Days of American Crime<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "The Last Days of American Crime", "marker": {"color": "#B6E880"}, "name": "The Last Days of American Crime", "offsetgroup": "The Last Days of American Crime", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Heist film/Thriller"], "xaxis": "x", "y": [3.7], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=Paradox<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Paradox", "marker": {"color": "#FF97FF"}, "name": "Paradox", "offsetgroup": "Paradox", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Musical/Western/Fantasy"], "xaxis": "x", "y": [3.9], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "T ...

# %% [markdown]
# # Above are Top Genres & movies which have ratings lower than 5

# %%
plt.figure(figsize = (28,9))
df.Genre.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Top genres fall in Documentary, Drama, Comedy, Romantic comedy, Thriller

# %%
genre_high = df[df['IMDB Score']>7][['Genre','Title', 'IMDB Score','Language']].sort_values('IMDB Score', ascending = True)

# %%
sns.catplot(x="Genre", kind="count", data=genre_high[:50], aspect= 50.7/11.2)

# %%
fig = px.bar(genre_high[:50], x='Genre', y= 'IMDB Score', color = 'Title')
fig.show()
# Out:
# <div>                            <div id="b29376e6-ef78-4f7c-a4cb-e7b9a0aa5fbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b29376e6-ef78-4f7c-a4cb-e7b9a0aa5fbb")) {                    Plotly.newPlot(                        "b29376e6-ef78-4f7c-a4cb-e7b9a0aa5fbb",                        [{"alignmentgroup": "True", "hovertemplate": "Title=13th: A Conversation with Oprah Winfrey & Ava DuVernay<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "13th: A Conversation with Oprah Winfrey & Ava DuVernay", "marker": {"color": "#636efa"}, "name": "13th: A Conversation with Oprah Winfrey & Ava DuVernay", "offsetgroup": "13th: A Conversation with Oprah Winfrey & Ava DuVernay", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Aftershow / Interview"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=To All the Boys I've Loved Before<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "To All the Boys I've Loved Before", "marker": {"color": "#EF553B"}, "name": "To All the Boys I've Loved Before", "offsetgroup": "To All the Boys I've Loved Before", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Romantic comedy"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=The White Tiger<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "The White Tiger", "marker": {"color": "#00cc96"}, "name": "The White Tiger", "offsetgroup": "The White Tiger", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Drama"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=The Great Hack<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "The Great Hack", "marker": {"color": "#ab63fa"}, "name": "The Great Hack", "offsetgroup": "The Great Hack", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Documentary"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=The Dig<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "The Dig", "marker": {"color": "#FFA15A"}, "name": "The Dig", "offsetgroup": "The Dig", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Drama"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=The Devil All the Time<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "The Devil All the Time", "marker": {"color": "#19d3f3"}, "name": "The Devil All the Time", "offsetgroup": "The Devil All the Time", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Psychological thriller"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=Rooting for Roona<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Rooting for Roona", "marker": {"color": "#FF6692"}, "name": "Rooting for Roona", "offsetgroup": "Rooting for Roona", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Documentary"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Title=ReMastered: Tricky Dick & the Man in Black<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "ReMastered: Tricky Dick & the Man in Black", "marker": {"color": "#B6E880"}, "name": "ReMastered: Tricky Dick & the Man in Black", "offsetgroup": "ReMastered: Tricky Dick & the Man in Black", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Documentary"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hove ...

# %% [markdown]
# # Above are the movies & Top genres where IMDB Score is greater than 7
#
# Move your cursor around the picture to get the details

# %%
genre_high[:25].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# # Top movies with ratings and Genre above 7 in pie chart
# Move your cursor around the picture to get the details

# %%
df['Genre'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='Genre'>

# %% [markdown]
# All genre

# %%
df['Language'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
fig = px.bar(genre_high[:50], x='Genre', y= 'IMDB Score', color = 'Language')
fig.show()
# Out:
# <div>                            <div id="4a30ff80-3ddd-4145-9af6-1ef1811da5e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a30ff80-3ddd-4145-9af6-1ef1811da5e2")) {                    Plotly.newPlot(                        "4a30ff80-3ddd-4145-9af6-1ef1811da5e2",                        [{"alignmentgroup": "True", "hovertemplate": "Language=English<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "English", "marker": {"color": "#636efa"}, "name": "English", "offsetgroup": "English", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Aftershow / Interview", "Romantic comedy", "Drama", "Documentary", "Drama", "Psychological thriller", "Documentary", "Documentary", "Drama", "Documentary", "One-man show", "Documentary", "Documentary", "Documentary", "Animation", "Documentary", "Drama", "Documentary", "Documentary", "Mentalism special", "Animation", "Documentary", "Documentary", "Documentary", "Documentary", "War", "Making-of", "Historical drama", "Comedy", "Documentary", "Drama-Comedy", "Documentary", "Documentary", "Documentary", "Documentary", "Drama", "Documentary"], "xaxis": "x", "y": [7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.1, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2, 7.2, 7.3], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Language=Bengali<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Bengali", "marker": {"color": "#EF553B"}, "name": "Bengali", "offsetgroup": "Bengali", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Documentary"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Language=Spanish<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Spanish", "marker": {"color": "#00cc96"}, "name": "Spanish", "offsetgroup": "Spanish", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Documentary", "Documentary", "Coming-of-age comedy-drama"], "xaxis": "x", "y": [7.1, 7.1, 7.2], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Language=Dutch<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Dutch", "marker": {"color": "#ab63fa"}, "name": "Dutch", "offsetgroup": "Dutch", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Crime drama"], "xaxis": "x", "y": [7.1], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Language=Tamil<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Tamil", "marker": {"color": "#FFA15A"}, "name": "Tamil", "offsetgroup": "Tamil", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Drama"], "xaxis": "x", "y": [7.2], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Language=Portuguese<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Portuguese", "marker": {"color": "#19d3f3"}, "name": "Portuguese", "offsetgroup": "Portuguese", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Documentary"], "xaxis": "x", "y": [7.2], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Language=Marathi<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Marathi", "marker": {"color": "#FF6692"}, "name": "Marathi", "offsetgroup": "Marathi", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Drama"], "xaxis": "x", "y": [7.2], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Language=Hindi<br>Genre=%{x}<br>IMDB Score=%{y}<extra></extra>", "legendgroup": "Hindi", "marker": {"color": "#B6E880"}, "name": "Hindi", "offsetgroup": "Hindi", "orientation":  ...

# %% [markdown]
# # Above are the genres with languages and IMDB Score with rating higher than 7

# %%
plt.figure(figsize = (12,12))
sns.barplot(x = 'IMDB Score', y = 'Title',hue ='Language', data = score_8)
# Out:
# <AxesSubplot:xlabel='IMDB Score', ylabel='Title'>

# %% [markdown]
# # Only 3 movies which has ratings over 8 are not in english language

# %%
sns.catplot(x="Language", kind="count", data=genre_low, aspect= 50.7/11.2)

# %% [markdown]
# # IMDB Movie ratings less than 5 and their languages

# %% [markdown]
# ## Please upvote if you like it :)
